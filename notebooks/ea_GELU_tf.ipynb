# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, LayerNormalization, MultiHeadAttention, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import get_file
from sklearn.metrics import precision_score, recall_score

# %%
# Download and preprocess the Imagenette dataset
def preprocess_image(image, label, image_size=(224, 224)):
    image = tf.image.resize(image, image_size)
    image = tf.image.convert_image_dtype(image, tf.float32)
    return image, label

def prepare_dataset(batch_size=32, image_size=(224, 224)):
    dataset_url = "https://s3.amazonaws.com/fast-ai-imageclas/imagenette2-160.tgz"
    dataset_path = get_file("imagenette2-160", dataset_url, untar=True)
    
    train_ds = tf.keras.utils.image_dataset_from_directory(
        dataset_path + "/train",
        image_size=image_size,
        batch_size=batch_size
    )
    
    val_ds = tf.keras.utils.image_dataset_from_directory(
        dataset_path + "/val",
        image_size=image_size,
        batch_size=batch_size
    )
    
    train_ds = train_ds.map(lambda x, y: preprocess_image(x, y, image_size)).cache().shuffle(1000).prefetch(tf.data.AUTOTUNE)
    val_ds = val_ds.map(lambda x, y: preprocess_image(x, y, image_size)).cache().prefetch(tf.data.AUTOTUNE)
    
    return train_ds, val_ds

# %%
# Gated Linear Unit (GLU) with GELU gating
class GatedLinearUnit(layers.Layer):
    def __init__(self, units):
        super(GatedLinearUnit, self).__init__()
        self.dense = layers.Dense(units * 2)  # Double the units for gating
        self.split = layers.Lambda(lambda x: tf.split(x, num_or_size_splits=2, axis=-1))

    def call(self, inputs):
        linear, gate = self.split(self.dense(inputs))
        gate = tf.nn.gelu(gate)  # GELU activation function
        return linear * gate

# %%
# Transformer Block
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, projection_dim, num_heads):
        super(TransformerBlock, self).__init__()
        self.attention = MultiHeadAttention(num_heads=num_heads, key_dim=projection_dim)
        self.dropout1 = Dropout(0.1)
        self.norm1 = LayerNormalization(epsilon=1e-6)

        self.glu = GatedLinearUnit(projection_dim)
        self.norm2 = LayerNormalization(epsilon=1e-6)

    def call(self, inputs, training=None):
        attention_output = self.attention(inputs, inputs)
        attention_output = self.dropout1(attention_output, training=training)
        out1 = self.norm1(inputs + attention_output)

        glu_output = self.glu(out1)
        return self.norm2(out1 + glu_output)

# %%
# Vision Transformer
class VisionTransformer(tf.keras.Model):
    def __init__(self, num_classes, input_shape=(224, 224, 3), patch_size=16, num_patches=196, projection_dim=64, num_heads=4, num_layers=8):
        super(VisionTransformer, self).__init__()
        self.num_classes = num_classes
        self.num_patches = num_patches
        self.patch_size = patch_size

        # Layers
        self.patch_embedding = layers.Conv2D(
            filters=projection_dim,
            kernel_size=patch_size,
            strides=patch_size,
            padding="valid"
        )
        self.pos_embedding = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)
        self.transformer_blocks = [
            TransformerBlock(projection_dim=projection_dim, num_heads=num_heads)
            for _ in range(num_layers)
        ]
        self.mlp_head = tf.keras.Sequential([
            layers.LayerNormalization(epsilon=1e-6),
            layers.Dense(128, activation="relu"),
            layers.Dropout(0.1),
            layers.Dense(num_classes)
        ])

    def call(self, inputs, training=None):
        # Extract patches
        batch_size = tf.shape(inputs)[0]
        patches = self.patch_embedding(inputs)
        patches = tf.reshape(patches, [batch_size, self.num_patches, -1])

        # Add positional embedding
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        positions = self.pos_embedding(positions)
        x = patches + positions

        # Apply Transformer blocks
        for transformer_block in self.transformer_blocks:
            x = transformer_block(x, training=training)

        x = x[:, 0]
        return self.mlp_head(x, training=training)

# %%
class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, train_ds, val_ds):
        super(MetricsCallback, self).__init__()
        self.train_ds = train_ds
        self.val_ds = val_ds
        self.best_epoch = -1
        self.best_val_accuracy = 0.0
        self.history = {"loss": [], "accuracy": [], "precision": [], "recall": [],
                        "val_loss": [], "val_accuracy": [], "val_precision": [], "val_recall": []}

    def on_epoch_end(self, epoch, logs=None):
        # Training metrics
        train_loss = logs.get("loss")
        train_accuracy = logs.get("accuracy")
        train_precision, train_recall = self.calculate_metrics(self.train_ds, self.model)
        
        # Validation metrics
        val_loss = logs.get("val_loss")
        val_accuracy = logs.get("val_accuracy")
        val_precision, val_recall = self.calculate_metrics(self.val_ds, self.model)

        # Update the best epoch if validation accuracy improves
        if val_accuracy > self.best_val_accuracy:
            self.best_val_accuracy = val_accuracy
            self.best_epoch = epoch

        # Save metrics to history
        self.history["loss"].append(train_loss)
        self.history["accuracy"].append(train_accuracy)
        self.history["precision"].append(train_precision)
        self.history["recall"].append(train_recall)
        self.history["val_loss"].append(val_loss)
        self.history["val_accuracy"].append(val_accuracy)
        self.history["val_precision"].append(val_precision)
        self.history["val_recall"].append(val_recall)

        # Print metrics for the epoch
        print(f"\nEpoch {epoch + 1}:")
        print(f"Train Metrics -> Loss: {train_loss:.4f}, Accuracy: {train_accuracy:.4f}, "
              f"Precision: {train_precision:.4f}, Recall: {train_recall:.4f}")
        print(f"Validation Metrics -> Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}, "
              f"Precision: {val_precision:.4f}, Recall: {val_recall:.4f}")
        print("-" * 10)

    def calculate_metrics(self, dataset, model):
        y_true, y_pred = [], []
        for x, y in dataset:
            preds = tf.argmax(model(x, training=False), axis=-1)
            y_true.extend(y.numpy())
            y_pred.extend(preds.numpy())

        precision = precision_score(y_true, y_pred, average="macro", zero_division=1)
        recall = recall_score(y_true, y_pred, average="macro", zero_division=1)
        return precision, recall

    def plot_metrics(self):
        metrics = ["loss", "accuracy", "precision", "recall"]
        for metric in metrics:
            plt.figure(figsize=(10, 6))
            train_metric = self.history[metric]
            val_metric = self.history[f"val_{metric}"]

            plt.plot(range(1, len(train_metric) + 1), train_metric, label=f"Train {metric.title()}")
            plt.plot(range(1, len(val_metric) + 1), val_metric, label=f"Validation {metric.title()}")

            best_epoch = self.best_epoch + 1
            best_value = self.history[f"val_{metric}"][self.best_epoch]
            plt.axvline(best_epoch, color='red', linestyle='--', label=f"Best Epoch")
            plt.axhline(best_value, color='green', linestyle='--', label=f"Best {metric.title()}")

            plt.title(f"{metric.title()} Over Epochs")
            plt.xlabel("Epochs")
            plt.ylabel(metric.title())
            plt.legend()
            plt.grid(True)
            plt.show()

# %%
# Train and Evaluate the Vision Transformer
def train_vit_with_metrics():
    train_ds, val_ds = prepare_dataset()
    test_ds = val_ds

    train_batches = len(train_ds)
    val_batches = len(val_ds)
    
    vit_model = VisionTransformer(num_classes=10, input_shape=(224, 224, 3))
    vit_model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=["accuracy"]
    )

    # Callbacks
    metrics_callback = MetricsCallback(train_ds, val_ds)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=3,
        min_lr=1e-6,
        verbose=1
    )

    # Train the model
    vit_model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=50,
        steps_per_epoch=train_batches,
        validation_steps=val_batches,
        callbacks=[metrics_callback, early_stopping, reduce_lr]
    )

    # Display metrics of the best epoch
    print(f"\nTraining Complete. Best Epoch: {metrics_callback.best_epoch + 1}")
    print(f"Training Metrics -> Loss: {metrics_callback.history['loss'][metrics_callback.best_epoch]:.4f}, "
          f"Accuracy: {metrics_callback.history['accuracy'][metrics_callback.best_epoch]:.4f}, "
          f"Precision: {metrics_callback.history['precision'][metrics_callback.best_epoch]:.4f}, "
          f"Recall: {metrics_callback.history['recall'][metrics_callback.best_epoch]:.4f}")
    print(f"Validation Metrics -> Loss: {metrics_callback.history['val_loss'][metrics_callback.best_epoch]:.4f}, "
          f"Accuracy: {metrics_callback.history['val_accuracy'][metrics_callback.best_epoch]:.4f}, "
          f"Precision: {metrics_callback.history['val_precision'][metrics_callback.best_epoch]:.4f}, "
          f"Recall: {metrics_callback.history['val_recall'][metrics_callback.best_epoch]:.4f}")

    # Evaluate the model on the test dataset using the best epoch
    test_loss, test_accuracy = vit_model.evaluate(test_ds)
    test_precision, test_recall = metrics_callback.calculate_metrics(test_ds, vit_model)
    print(f"\nTest Metrics -> Loss: {test_loss:.4f}, Accuracy: {test_accuracy:.4f}, "
          f"Precision: {test_precision:.4f}, Recall: {test_recall:.4f}")

    # Generate and display the plots
    metrics_callback.plot_metrics()

# Call the function to start training
train_vit_with_metrics()
# Out:
# Found 9469 files belonging to 10 classes.
# Found 3925 files belonging to 10 classes.
# Epoch 1/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 790ms/step - accuracy: 0.1682 - loss: 2.2492
# Epoch 1:
# Train Metrics -> Loss: 2.1740, Accuracy: 0.2015, Precision: 0.3154, Recall: 0.2942
# Validation Metrics -> Loss: 2.0036, Accuracy: 0.2823, Precision: 0.2648, Recall: 0.2834
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 461s 2s/step - accuracy: 0.1683 - loss: 2.2489 - val_accuracy: 0.2823 - val_loss: 2.0036 - learning_rate: 1.0000e-04
# Epoch 2/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.2675 - loss: 2.0163
# Epoch 2:
# Train Metrics -> Loss: 1.9869, Accuracy: 0.2809, Precision: 0.3424, Recall: 0.3488
# Validation Metrics -> Loss: 1.8708, Accuracy: 0.3343, Precision: 0.3234, Recall: 0.3363
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 495s 2s/step - accuracy: 0.2676 - loss: 2.0162 - val_accuracy: 0.3343 - val_loss: 1.8708 - learning_rate: 1.0000e-04
# Epoch 3/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.3312 - loss: 1.8938
# Epoch 3:
# Train Metrics -> Loss: 1.8665, Accuracy: 0.3423, Precision: 0.4164, Recall: 0.4058
# Validation Metrics -> Loss: 1.7704, Accuracy: 0.3885, Precision: 0.4071, Recall: 0.3906
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 447s 2s/step - accuracy: 0.3313 - loss: 1.8937 - val_accuracy: 0.3885 - val_loss: 1.7704 - learning_rate: 1.0000e-04
# Epoch 4/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.3787 - loss: 1.7931
# Epoch 4:
# Train Metrics -> Loss: 1.7821, Accuracy: 0.3818, Precision: 0.4650, Recall: 0.3783
# Validation Metrics -> Loss: 1.8046, Accuracy: 0.3712, Precision: 0.4708, Recall: 0.3712
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 452s 2s/step - accuracy: 0.3787 - loss: 1.7930 - val_accuracy: 0.3712 - val_loss: 1.8046 - learning_rate: 1.0000e-04
# Epoch 5/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 694ms/step - accuracy: 0.4091 - loss: 1.7197
# Epoch 5:
# Train Metrics -> Loss: 1.6943, Accuracy: 0.4196, Precision: 0.4640, Recall: 0.4403
# Validation Metrics -> Loss: 1.6801, Accuracy: 0.4242, Precision: 0.4513, Recall: 0.4268
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 441s 1s/step - accuracy: 0.4091 - loss: 1.7196 - val_accuracy: 0.4242 - val_loss: 1.6801 - learning_rate: 1.0000e-04
# Epoch 6/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 690ms/step - accuracy: 0.4235 - loss: 1.6729
# Epoch 6:
# Train Metrics -> Loss: 1.6629, Accuracy: 0.4265, Precision: 0.4243, Recall: 0.4207
# Validation Metrics -> Loss: 1.7243, Accuracy: 0.4061, Precision: 0.4028, Recall: 0.4077
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 440s 1s/step - accuracy: 0.4236 - loss: 1.6728 - val_accuracy: 0.4061 - val_loss: 1.7243 - learning_rate: 1.0000e-04
# Epoch 7/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.4434 - loss: 1.6072
# Epoch 7:
# Train Metrics -> Loss: 1.6051, Accuracy: 0.4485, Precision: 0.4853, Recall: 0.4810
# Validation Metrics -> Loss: 1.5941, Accuracy: 0.4629, Precision: 0.4674, Recall: 0.4659
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 437s 1s/step - accuracy: 0.4434 - loss: 1.6072 - val_accuracy: 0.4629 - val_loss: 1.5941 - learning_rate: 1.0000e-04
# Epoch 8/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 681ms/step - accuracy: 0.4681 - loss: 1.5341
# Epoch 8:
# Train Metrics -> Loss: 1.5554, Accuracy: 0.4672, Precision: 0.5168, Recall: 0.5005
# Validation Metrics -> Loss: 1.5311, Accuracy: 0.4818, Precision: 0.4972, Recall: 0.4823
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - accuracy: 0.4681 - loss: 1.5342 - val_accuracy: 0.4818 - val_loss: 1.5311 - learning_rate: 1.0000e-04
# Epoch 9/50
# 2024-12-10 02:00:55.103521: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 680ms/step - accuracy: 0.4802 - loss: 1.5223
# Epoch 9:
# Train Metrics -> Loss: 1.5309, Accuracy: 0.4819, Precision: 0.5329, Recall: 0.5151
# Validation Metrics -> Loss: 1.5268, Accuracy: 0.4859, Precision: 0.5055, Recall: 0.4870
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 453s 2s/step - accuracy: 0.4802 - loss: 1.5223 - val_accuracy: 0.4859 - val_loss: 1.5268 - learning_rate: 1.0000e-04
# Epoch 10/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 668ms/step - accuracy: 0.4990 - loss: 1.4767
# Epoch 10:
# Train Metrics -> Loss: 1.4793, Accuracy: 0.5016, Precision: 0.5378, Recall: 0.5295
# Validation Metrics -> Loss: 1.5108, Accuracy: 0.4925, Precision: 0.4997, Recall: 0.4943
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 454s 2s/step - accuracy: 0.4990 - loss: 1.4767 - val_accuracy: 0.4925 - val_loss: 1.5108 - learning_rate: 1.0000e-04
# Epoch 11/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 650ms/step - accuracy: 0.5132 - loss: 1.4552
# Epoch 11:
# Train Metrics -> Loss: 1.4653, Accuracy: 0.5077, Precision: 0.5312, Recall: 0.4989
# Validation Metrics -> Loss: 1.6054, Accuracy: 0.4568, Precision: 0.4855, Recall: 0.4596
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 443s 2s/step - accuracy: 0.5132 - loss: 1.4553 - val_accuracy: 0.4568 - val_loss: 1.6054 - learning_rate: 1.0000e-04
# Epoch 12/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 657ms/step - accuracy: 0.5020 - loss: 1.4650
# Epoch 12:
# Train Metrics -> Loss: 1.4496, Accuracy: 0.5096, Precision: 0.5611, Recall: 0.5531
# Validation Metrics -> Loss: 1.4584, Accuracy: 0.5062, Precision: 0.5169, Recall: 0.5082
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 449s 2s/step - accuracy: 0.5020 - loss: 1.4650 - val_accuracy: 0.5062 - val_loss: 1.4584 - learning_rate: 1.0000e-04
# Epoch 13/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 644ms/step - accuracy: 0.5260 - loss: 1.4051
# Epoch 13:
# Train Metrics -> Loss: 1.4082, Accuracy: 0.5260, Precision: 0.5688, Recall: 0.5646
# Validation Metrics -> Loss: 1.4500, Accuracy: 0.5162, Precision: 0.5218, Recall: 0.5180
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 449s 2s/step - accuracy: 0.5260 - loss: 1.4051 - val_accuracy: 0.5162 - val_loss: 1.4500 - learning_rate: 1.0000e-04
# Epoch 14/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - accuracy: 0.5453 - loss: 1.3456
# Epoch 14:
# Train Metrics -> Loss: 1.3412, Accuracy: 0.5480, Precision: 0.6049, Recall: 0.5872
# Validation Metrics -> Loss: 1.4040, Accuracy: 0.5233, Precision: 0.5396, Recall: 0.5247
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 441s 1s/step - accuracy: 0.5453 - loss: 1.3456 - val_accuracy: 0.5233 - val_loss: 1.4040 - learning_rate: 1.0000e-04
# Epoch 15/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.5728 - loss: 1.2781
# Epoch 15:
# Train Metrics -> Loss: 1.2953, Accuracy: 0.5673, Precision: 0.5970, Recall: 0.5926
# Validation Metrics -> Loss: 1.3982, Accuracy: 0.5376, Precision: 0.5418, Recall: 0.5390
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 444s 2s/step - accuracy: 0.5728 - loss: 1.2782 - val_accuracy: 0.5376 - val_loss: 1.3982 - learning_rate: 1.0000e-04
# Epoch 16/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 644ms/step - accuracy: 0.5624 - loss: 1.3138
# Epoch 16:
# Train Metrics -> Loss: 1.2889, Accuracy: 0.5685, Precision: 0.6232, Recall: 0.5995
# Validation Metrics -> Loss: 1.3935, Accuracy: 0.5383, Precision: 0.5655, Recall: 0.5401
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - accuracy: 0.5625 - loss: 1.3137 - val_accuracy: 0.5383 - val_loss: 1.3935 - learning_rate: 1.0000e-04
# Epoch 17/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 646ms/step - accuracy: 0.5913 - loss: 1.2270
# Epoch 17:
# Train Metrics -> Loss: 1.2496, Accuracy: 0.5841, Precision: 0.6117, Recall: 0.5999
# Validation Metrics -> Loss: 1.4069, Accuracy: 0.5348, Precision: 0.5471, Recall: 0.5375
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 443s 1s/step - accuracy: 0.5913 - loss: 1.2270 - val_accuracy: 0.5348 - val_loss: 1.4069 - learning_rate: 1.0000e-04
# Epoch 18/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 644ms/step - accuracy: 0.5785 - loss: 1.2462
# Epoch 18:
# Train Metrics -> Loss: 1.2545, Accuracy: 0.5763, Precision: 0.6212, Recall: 0.6163
# Validation Metrics -> Loss: 1.3512, Accuracy: 0.5478, Precision: 0.5536, Recall: 0.5494
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 484s 2s/step - accuracy: 0.5785 - loss: 1.2463 - val_accuracy: 0.5478 - val_loss: 1.3512 - learning_rate: 1.0000e-04
# Epoch 19/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - accuracy: 0.5981 - loss: 1.2041
# Epoch 19:
# Train Metrics -> Loss: 1.2111, Accuracy: 0.5946, Precision: 0.6412, Recall: 0.6253
# Validation Metrics -> Loss: 1.3509, Accuracy: 0.5508, Precision: 0.5632, Recall: 0.5510
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 433s 1s/step - accuracy: 0.5981 - loss: 1.2042 - val_accuracy: 0.5508 - val_loss: 1.3509 - learning_rate: 1.0000e-04
# Epoch 20/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - accuracy: 0.6010 - loss: 1.1996
# Epoch 20:
# Train Metrics -> Loss: 1.1873, Accuracy: 0.6025, Precision: 0.6501, Recall: 0.6376
# Validation Metrics -> Loss: 1.3318, Accuracy: 0.5559, Precision: 0.5617, Recall: 0.5576
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 437s 1s/step - accuracy: 0.6010 - loss: 1.1995 - val_accuracy: 0.5559 - val_loss: 1.3318 - learning_rate: 1.0000e-04
# Epoch 21/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.6267 - loss: 1.1262
# Epoch 21:
# Train Metrics -> Loss: 1.1614, Accuracy: 0.6116, Precision: 0.6617, Recall: 0.6549
# Validation Metrics -> Loss: 1.3131, Accuracy: 0.5641, Precision: 0.5670, Recall: 0.5659
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - accuracy: 0.6267 - loss: 1.1264 - val_accuracy: 0.5641 - val_loss: 1.3131 - learning_rate: 1.0000e-04
# Epoch 22/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 679ms/step - accuracy: 0.6180 - loss: 1.1304
# Epoch 22:
# Train Metrics -> Loss: 1.1478, Accuracy: 0.6121, Precision: 0.6484, Recall: 0.6225
# Validation Metrics -> Loss: 1.3887, Accuracy: 0.5422, Precision: 0.5622, Recall: 0.5454
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 437s 1s/step - accuracy: 0.6180 - loss: 1.1304 - val_accuracy: 0.5422 - val_loss: 1.3887 - learning_rate: 1.0000e-04
# Epoch 23/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 675ms/step - accuracy: 0.6447 - loss: 1.0879
# Epoch 23:
# Train Metrics -> Loss: 1.0991, Accuracy: 0.6368, Precision: 0.6596, Recall: 0.6545
# Validation Metrics -> Loss: 1.3326, Accuracy: 0.5646, Precision: 0.5695, Recall: 0.5666
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 465s 2s/step - accuracy: 0.6447 - loss: 1.0879 - val_accuracy: 0.5646 - val_loss: 1.3326 - learning_rate: 1.0000e-04
# Epoch 24/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 668ms/step - accuracy: 0.6325 - loss: 1.0906
# Epoch 24:
# Train Metrics -> Loss: 1.0883, Accuracy: 0.6329, Precision: 0.6778, Recall: 0.6738
# Validation Metrics -> Loss: 1.2969, Accuracy: 0.5722, Precision: 0.5735, Recall: 0.5739
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 432s 1s/step - accuracy: 0.6325 - loss: 1.0906 - val_accuracy: 0.5722 - val_loss: 1.2969 - learning_rate: 1.0000e-04
# Epoch 25/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 710ms/step - accuracy: 0.6456 - loss: 1.0645
# Epoch 25:
# Train Metrics -> Loss: 1.0742, Accuracy: 0.6413, Precision: 0.6591, Recall: 0.6395
# Validation Metrics -> Loss: 1.3656, Accuracy: 0.5580, Precision: 0.5753, Recall: 0.5592
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 444s 2s/step - accuracy: 0.6456 - loss: 1.0645 - val_accuracy: 0.5580 - val_loss: 1.3656 - learning_rate: 1.0000e-04
# Epoch 26/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 685ms/step - accuracy: 0.6630 - loss: 1.0063
# Epoch 26:
# Train Metrics -> Loss: 1.0327, Accuracy: 0.6555, Precision: 0.6996, Recall: 0.6917
# Validation Metrics -> Loss: 1.2937, Accuracy: 0.5773, Precision: 0.5780, Recall: 0.5789
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 494s 1s/step - accuracy: 0.6630 - loss: 1.0064 - val_accuracy: 0.5773 - val_loss: 1.2937 - learning_rate: 1.0000e-04
# Epoch 27/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 679ms/step - accuracy: 0.6657 - loss: 1.0113
# Epoch 27:
# Train Metrics -> Loss: 1.0465, Accuracy: 0.6506, Precision: 0.6862, Recall: 0.6835
# Validation Metrics -> Loss: 1.3058, Accuracy: 0.5758, Precision: 0.5782, Recall: 0.5776
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 441s 1s/step - accuracy: 0.6657 - loss: 1.0114 - val_accuracy: 0.5758 - val_loss: 1.3058 - learning_rate: 1.0000e-04
# Epoch 28/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 676ms/step - accuracy: 0.6633 - loss: 1.0070
# Epoch 28:
# Train Metrics -> Loss: 1.0224, Accuracy: 0.6606, Precision: 0.7135, Recall: 0.7013
# Validation Metrics -> Loss: 1.2978, Accuracy: 0.5771, Precision: 0.5882, Recall: 0.5779
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 437s 1s/step - accuracy: 0.6633 - loss: 1.0071 - val_accuracy: 0.5771 - val_loss: 1.2978 - learning_rate: 1.0000e-04
# Epoch 29/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 687ms/step - accuracy: 0.6779 - loss: 0.9643
# Epoch 29:
# Train Metrics -> Loss: 1.0029, Accuracy: 0.6631, Precision: 0.6908, Recall: 0.6902
# Validation Metrics -> Loss: 1.3079, Accuracy: 0.5781, Precision: 0.5791, Recall: 0.5796
# ----------
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 440s 1s/step - accuracy: 0.6778 - loss: 0.9644 - val_accuracy: 0.5781 - val_loss: 1.3079 - learning_rate: 1.0000e-04
# Epoch 30/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 685ms/step - accuracy: 0.6796 - loss: 0.9532
# Epoch 30:
# Train Metrics -> Loss: 0.9376, Accuracy: 0.6872, Precision: 0.7323, Recall: 0.7272
# Validation Metrics -> Loss: 1.2665, Accuracy: 0.5885, Precision: 0.5966, Recall: 0.5888
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 446s 2s/step - accuracy: 0.6797 - loss: 0.9532 - val_accuracy: 0.5885 - val_loss: 1.2665 - learning_rate: 5.0000e-05
# Epoch 31/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 679ms/step - accuracy: 0.7023 - loss: 0.8820
# Epoch 31:
# Train Metrics -> Loss: 0.8915, Accuracy: 0.7008, Precision: 0.7398, Recall: 0.7341
# Validation Metrics -> Loss: 1.2779, Accuracy: 0.5906, Precision: 0.5971, Recall: 0.5910
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 444s 2s/step - accuracy: 0.7023 - loss: 0.8821 - val_accuracy: 0.5906 - val_loss: 1.2779 - learning_rate: 5.0000e-05
# Epoch 32/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 670ms/step - accuracy: 0.7124 - loss: 0.8683
# Epoch 32:
# Train Metrics -> Loss: 0.8902, Accuracy: 0.7029, Precision: 0.7381, Recall: 0.7362
# Validation Metrics -> Loss: 1.2778, Accuracy: 0.5847, Precision: 0.5874, Recall: 0.5860
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - accuracy: 0.7124 - loss: 0.8683 - val_accuracy: 0.5847 - val_loss: 1.2778 - learning_rate: 5.0000e-05
# Epoch 33/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 669ms/step - accuracy: 0.7126 - loss: 0.8628
# Epoch 33:
# Train Metrics -> Loss: 0.8612, Accuracy: 0.7167, Precision: 0.7497, Recall: 0.7422
# Validation Metrics -> Loss: 1.2756, Accuracy: 0.5865, Precision: 0.5896, Recall: 0.5876
# ----------
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 445s 2s/step - accuracy: 0.7127 - loss: 0.8628 - val_accuracy: 0.5865 - val_loss: 1.2756 - learning_rate: 5.0000e-05
# Epoch 34/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - accuracy: 0.7363 - loss: 0.8065
# Epoch 34:
# Train Metrics -> Loss: 0.8204, Accuracy: 0.7313, Precision: 0.7596, Recall: 0.7556
# Validation Metrics -> Loss: 1.2681, Accuracy: 0.5959, Precision: 0.6015, Recall: 0.5967
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 438s 1s/step - accuracy: 0.7362 - loss: 0.8066 - val_accuracy: 0.5959 - val_loss: 1.2681 - learning_rate: 2.5000e-05
# Epoch 35/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 666ms/step - accuracy: 0.7366 - loss: 0.7907
# Epoch 35:
# Train Metrics -> Loss: 0.8016, Accuracy: 0.7345, Precision: 0.7633, Recall: 0.7632
# Validation Metrics -> Loss: 1.2648, Accuracy: 0.5969, Precision: 0.5962, Recall: 0.5977
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 442s 1s/step - accuracy: 0.7366 - loss: 0.7908 - val_accuracy: 0.5969 - val_loss: 1.2648 - learning_rate: 2.5000e-05
# Epoch 36/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 662ms/step - accuracy: 0.7388 - loss: 0.7941
# Epoch 36:
# Train Metrics -> Loss: 0.7882, Accuracy: 0.7413, Precision: 0.7697, Recall: 0.7690
# Validation Metrics -> Loss: 1.2637, Accuracy: 0.5985, Precision: 0.5989, Recall: 0.5995
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 491s 2s/step - accuracy: 0.7388 - loss: 0.7941 - val_accuracy: 0.5985 - val_loss: 1.2637 - learning_rate: 2.5000e-05
# Epoch 37/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 659ms/step - accuracy: 0.7418 - loss: 0.8007
# Epoch 37:
# Train Metrics -> Loss: 0.7882, Accuracy: 0.7438, Precision: 0.7783, Recall: 0.7783
# Validation Metrics -> Loss: 1.2506, Accuracy: 0.5992, Precision: 0.5990, Recall: 0.6003
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 441s 1s/step - accuracy: 0.7418 - loss: 0.8006 - val_accuracy: 0.5992 - val_loss: 1.2506 - learning_rate: 2.5000e-05
# Epoch 38/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 658ms/step - accuracy: 0.7458 - loss: 0.7723
# Epoch 38:
# Train Metrics -> Loss: 0.7664, Accuracy: 0.7466, Precision: 0.7634, Recall: 0.7625
# Validation Metrics -> Loss: 1.2752, Accuracy: 0.5944, Precision: 0.5958, Recall: 0.5954
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 438s 1s/step - accuracy: 0.7458 - loss: 0.7723 - val_accuracy: 0.5944 - val_loss: 1.2752 - learning_rate: 2.5000e-05
# Epoch 39/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 658ms/step - accuracy: 0.7469 - loss: 0.7735
# Epoch 39:
# Train Metrics -> Loss: 0.7687, Accuracy: 0.7495, Precision: 0.7867, Recall: 0.7837
# Validation Metrics -> Loss: 1.2717, Accuracy: 0.5962, Precision: 0.5995, Recall: 0.5970
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 442s 1s/step - accuracy: 0.7469 - loss: 0.7735 - val_accuracy: 0.5962 - val_loss: 1.2717 - learning_rate: 2.5000e-05
# Epoch 40/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - accuracy: 0.7585 - loss: 0.7487
# Epoch 40:
# Train Metrics -> Loss: 0.7477, Accuracy: 0.7572, Precision: 0.7922, Recall: 0.7909
# Validation Metrics -> Loss: 1.2686, Accuracy: 0.5985, Precision: 0.6020, Recall: 0.5996
# ----------
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 445s 2s/step - accuracy: 0.7585 - loss: 0.7487 - val_accuracy: 0.5985 - val_loss: 1.2686 - learning_rate: 2.5000e-05
# Epoch 41/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 673ms/step - accuracy: 0.7632 - loss: 0.7206
# Epoch 41:
# Train Metrics -> Loss: 0.7142, Accuracy: 0.7664, Precision: 0.7957, Recall: 0.7951
# Validation Metrics -> Loss: 1.2622, Accuracy: 0.6025, Precision: 0.6038, Recall: 0.6038
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 443s 1s/step - accuracy: 0.7632 - loss: 0.7206 - val_accuracy: 0.6025 - val_loss: 1.2622 - learning_rate: 1.2500e-05
# Epoch 42/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - accuracy: 0.7645 - loss: 0.7157
# Epoch 42:
# Train Metrics -> Loss: 0.7021, Accuracy: 0.7721, Precision: 0.8026, Recall: 0.8027
# Validation Metrics -> Loss: 1.2700, Accuracy: 0.6020, Precision: 0.6021, Recall: 0.6027
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 438s 1s/step - accuracy: 0.7645 - loss: 0.7156 - val_accuracy: 0.6020 - val_loss: 1.2700 - learning_rate: 1.2500e-05
#
# Training Complete. Best Epoch: 41
# Training Metrics -> Loss: 0.7142, Accuracy: 0.7664, Precision: 0.7957, Recall: 0.7951
# Validation Metrics -> Loss: 1.2622, Accuracy: 0.6025, Precision: 0.6038, Recall: 0.6038
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 34s 277ms/step - accuracy: 0.5956 - loss: 1.2421
#
# Test Metrics -> Loss: 1.2506, Accuracy: 0.5992, Precision: 0.5990, Recall: 0.6003
