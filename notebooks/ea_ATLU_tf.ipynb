# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, LayerNormalization, MultiHeadAttention, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import get_file
from sklearn.metrics import precision_score, recall_score

# %%
# Download and preprocess the Imagenette dataset
def preprocess_image(image, label, image_size=(224, 224)):
    image = tf.image.resize(image, image_size)
    image = tf.image.convert_image_dtype(image, tf.float32)
    return image, label

def prepare_dataset(batch_size=32, image_size=(224, 224)):
    dataset_url = "https://s3.amazonaws.com/fast-ai-imageclas/imagenette2-160.tgz"
    dataset_path = get_file("imagenette2-160", dataset_url, untar=True)
    
    train_ds = tf.keras.utils.image_dataset_from_directory(
        dataset_path + "/train",
        image_size=image_size,
        batch_size=batch_size
    )
    
    val_ds = tf.keras.utils.image_dataset_from_directory(
        dataset_path + "/val",
        image_size=image_size,
        batch_size=batch_size
    )
    
    train_ds = train_ds.map(lambda x, y: preprocess_image(x, y, image_size)).cache().shuffle(1000).prefetch(tf.data.AUTOTUNE)
    val_ds = val_ds.map(lambda x, y: preprocess_image(x, y, image_size)).cache().prefetch(tf.data.AUTOTUNE)
    
    return train_ds, val_ds

# %%
# Gated Linear Unit (GLU) with ArcTan Function
class GatedLinearUnit(layers.Layer):
    def __init__(self, units):
        super(GatedLinearUnit, self).__init__()
        self.dense = Dense(units * 2)  # Double the units for gating
        self.split = layers.Lambda(lambda x: tf.split(x, num_or_size_splits=2, axis=-1))

    def call(self, inputs):
        linear, gate = self.split(self.dense(inputs))
        return linear * tf.math.atan(gate)

# %%
# Transformer Block
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, projection_dim, num_heads):
        super(TransformerBlock, self).__init__()
        self.attention = MultiHeadAttention(num_heads=num_heads, key_dim=projection_dim)
        self.dropout1 = Dropout(0.1)
        self.norm1 = LayerNormalization(epsilon=1e-6)

        self.glu = GatedLinearUnit(projection_dim)
        self.norm2 = LayerNormalization(epsilon=1e-6)

    def call(self, inputs, training=None):
        attention_output = self.attention(inputs, inputs)
        attention_output = self.dropout1(attention_output, training=training)
        out1 = self.norm1(inputs + attention_output)

        glu_output = self.glu(out1)
        return self.norm2(out1 + glu_output)

# %%
# Vision Transformer
class VisionTransformer(tf.keras.Model):
    def __init__(self, num_classes, input_shape, patch_size=16, num_patches=196, projection_dim=64, num_heads=4, num_layers=8):
        super(VisionTransformer, self).__init__()
        self.num_classes = num_classes
        self.num_patches = num_patches
        self.patch_size = patch_size

        # Layers
        self.patch_embedding = layers.Conv2D(
            filters=projection_dim,
            kernel_size=patch_size,
            strides=patch_size,
            padding="valid"
        )
        self.pos_embedding = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)
        self.transformer_blocks = [
            TransformerBlock(projection_dim=projection_dim, num_heads=num_heads)
            for _ in range(num_layers)
        ]
        self.mlp_head = tf.keras.Sequential([
            layers.LayerNormalization(epsilon=1e-6),
            layers.Dense(128, activation="relu"),
            layers.Dropout(0.1),
            layers.Dense(num_classes)
        ])

    def call(self, inputs, training=None):
        # Extract patches
        batch_size = tf.shape(inputs)[0]
        patches = self.patch_embedding(inputs)
        patches = tf.reshape(patches, [batch_size, self.num_patches, -1])

        # Add positional embedding
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        positions = self.pos_embedding(positions)
        x = patches + positions

        # Apply Transformer blocks
        for transformer_block in self.transformer_blocks:
            x = transformer_block(x, training=training)

        # Extract the [CLS] token and pass through MLP
        x = x[:, 0]
        return self.mlp_head(x, training=training)

# %%
class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, train_ds, val_ds):
        super(MetricsCallback, self).__init__()
        self.train_ds = train_ds
        self.val_ds = val_ds
        self.best_epoch = -1
        self.best_val_accuracy = 0.0
        self.history = {"loss": [], "accuracy": [], "precision": [], "recall": [],
                        "val_loss": [], "val_accuracy": [], "val_precision": [], "val_recall": []}

    def on_epoch_end(self, epoch, logs=None):
        # Training metrics
        train_loss = logs.get("loss")
        train_accuracy = logs.get("accuracy")
        train_precision, train_recall = self.calculate_metrics(self.train_ds, self.model)
        
        # Validation metrics
        val_loss = logs.get("val_loss")
        val_accuracy = logs.get("val_accuracy")
        val_precision, val_recall = self.calculate_metrics(self.val_ds, self.model)

        # Update the best epoch if validation accuracy improves
        if val_accuracy > self.best_val_accuracy:
            self.best_val_accuracy = val_accuracy
            self.best_epoch = epoch

        # Save metrics to history
        self.history["loss"].append(train_loss)
        self.history["accuracy"].append(train_accuracy)
        self.history["precision"].append(train_precision)
        self.history["recall"].append(train_recall)
        self.history["val_loss"].append(val_loss)
        self.history["val_accuracy"].append(val_accuracy)
        self.history["val_precision"].append(val_precision)
        self.history["val_recall"].append(val_recall)

        # Print metrics for the epoch
        print(f"\nEpoch {epoch + 1}:")
        print(f"Train Metrics -> Loss: {train_loss:.4f}, Accuracy: {train_accuracy:.4f}, "
              f"Precision: {train_precision:.4f}, Recall: {train_recall:.4f}")
        print(f"Validation Metrics -> Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}, "
              f"Precision: {val_precision:.4f}, Recall: {val_recall:.4f}")
        print("-" * 10)

    def calculate_metrics(self, dataset, model):
        y_true, y_pred = [], []
        for x, y in dataset:
            preds = tf.argmax(model(x, training=False), axis=-1)
            y_true.extend(y.numpy())
            y_pred.extend(preds.numpy())

        precision = precision_score(y_true, y_pred, average="macro", zero_division=1)
        recall = recall_score(y_true, y_pred, average="macro", zero_division=1)
        return precision, recall

    def plot_metrics(self):
        metrics = ["loss", "accuracy", "precision", "recall"]
        for metric in metrics:
            plt.figure(figsize=(10, 6))
            train_metric = self.history[metric]
            val_metric = self.history[f"val_{metric}"]

            plt.plot(range(1, len(train_metric) + 1), train_metric, label=f"Train {metric.title()}")
            plt.plot(range(1, len(val_metric) + 1), val_metric, label=f"Validation {metric.title()}")

            best_epoch = self.best_epoch + 1
            best_value = self.history[f"val_{metric}"][self.best_epoch]
            plt.axvline(best_epoch, color='red', linestyle='--', label=f"Best Epoch")
            plt.axhline(best_value, color='green', linestyle='--', label=f"Best {metric.title()}")

            plt.title(f"{metric.title()} Over Epochs")
            plt.xlabel("Epochs")
            plt.ylabel(metric.title())
            plt.legend()
            plt.grid(True)
            plt.show()

# %%
# Train and Evaluate the Vision Transformer
def train_vit_with_metrics():
    train_ds, val_ds = prepare_dataset()
    test_ds = val_ds

    train_batches = len(train_ds)
    val_batches = len(val_ds)
    
    vit_model = VisionTransformer(num_classes=10, input_shape=(224, 224, 3))
    vit_model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=["accuracy"]
    )

    # Callbacks
    metrics_callback = MetricsCallback(train_ds, val_ds)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=3,
        min_lr=1e-6,
        verbose=1
    )

    # Train the model
    vit_model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=50,
        steps_per_epoch=train_batches,
        validation_steps=val_batches,
        callbacks=[metrics_callback, early_stopping, reduce_lr]
    )

    # Display metrics of the best epoch
    print(f"\nTraining Complete. Best Epoch: {metrics_callback.best_epoch + 1}")
    print(f"Training Metrics -> Loss: {metrics_callback.history['loss'][metrics_callback.best_epoch]:.4f}, "
          f"Accuracy: {metrics_callback.history['accuracy'][metrics_callback.best_epoch]:.4f}, "
          f"Precision: {metrics_callback.history['precision'][metrics_callback.best_epoch]:.4f}, "
          f"Recall: {metrics_callback.history['recall'][metrics_callback.best_epoch]:.4f}")
    print(f"Validation Metrics -> Loss: {metrics_callback.history['val_loss'][metrics_callback.best_epoch]:.4f}, "
          f"Accuracy: {metrics_callback.history['val_accuracy'][metrics_callback.best_epoch]:.4f}, "
          f"Precision: {metrics_callback.history['val_precision'][metrics_callback.best_epoch]:.4f}, "
          f"Recall: {metrics_callback.history['val_recall'][metrics_callback.best_epoch]:.4f}")

    # Evaluate the model on the test dataset using the best epoch
    test_loss, test_accuracy = vit_model.evaluate(test_ds)
    test_precision, test_recall = metrics_callback.calculate_metrics(test_ds, vit_model)
    print(f"\nTest Metrics -> Loss: {test_loss:.4f}, Accuracy: {test_accuracy:.4f}, "
          f"Precision: {test_precision:.4f}, Recall: {test_recall:.4f}")

    # Generate and display the plots
    metrics_callback.plot_metrics()

# Call the function to start training
train_vit_with_metrics()
# Out:
# Found 9469 files belonging to 10 classes.
# Found 3925 files belonging to 10 classes.
# Epoch 1/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 783ms/step - accuracy: 0.1629 - loss: 2.2690
# Epoch 1:
# Train Metrics -> Loss: 2.1887, Accuracy: 0.1936, Precision: 0.2922, Recall: 0.2489
# Validation Metrics -> Loss: 2.0895, Accuracy: 0.2329, Precision: 0.2420, Recall: 0.2345
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 442s 1s/step - accuracy: 0.1630 - loss: 2.2688 - val_accuracy: 0.2329 - val_loss: 2.0895 - learning_rate: 1.0000e-04
# Epoch 2/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 723ms/step - accuracy: 0.2649 - loss: 2.0645
# Epoch 2:
# Train Metrics -> Loss: 2.0409, Accuracy: 0.2706, Precision: 0.3322, Recall: 0.3218
# Validation Metrics -> Loss: 1.9397, Accuracy: 0.3093, Precision: 0.3183, Recall: 0.3118
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 426s 1s/step - accuracy: 0.2649 - loss: 2.0644 - val_accuracy: 0.3093 - val_loss: 1.9397 - learning_rate: 1.0000e-04
# Epoch 3/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.3188 - loss: 1.9348
# Epoch 3:
# Train Metrics -> Loss: 1.9094, Accuracy: 0.3241, Precision: 0.3358, Recall: 0.3533
# Validation Metrics -> Loss: 1.8731, Accuracy: 0.3409, Precision: 0.3182, Recall: 0.3429
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 425s 1s/step - accuracy: 0.3188 - loss: 1.9347 - val_accuracy: 0.3409 - val_loss: 1.8731 - learning_rate: 1.0000e-04
# Epoch 4/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - accuracy: 0.3679 - loss: 1.8326
# 2024-12-10 01:28:43.909978: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 4:
# Train Metrics -> Loss: 1.8099, Accuracy: 0.3711, Precision: 0.4331, Recall: 0.3978
# Validation Metrics -> Loss: 1.7831, Accuracy: 0.3855, Precision: 0.4294, Recall: 0.3895
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 432s 1s/step - accuracy: 0.3679 - loss: 1.8325 - val_accuracy: 0.3855 - val_loss: 1.7831 - learning_rate: 1.0000e-04
# Epoch 5/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.3712 - loss: 1.7829
# Epoch 5:
# Train Metrics -> Loss: 1.7555, Accuracy: 0.3836, Precision: 0.4463, Recall: 0.4196
# Validation Metrics -> Loss: 1.7316, Accuracy: 0.3990, Precision: 0.4302, Recall: 0.4020
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 425s 1s/step - accuracy: 0.3712 - loss: 1.7828 - val_accuracy: 0.3990 - val_loss: 1.7316 - learning_rate: 1.0000e-04
# Epoch 6/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.4102 - loss: 1.7037
# Epoch 6:
# Train Metrics -> Loss: 1.6838, Accuracy: 0.4185, Precision: 0.4508, Recall: 0.4421
# Validation Metrics -> Loss: 1.6850, Accuracy: 0.4191, Precision: 0.4282, Recall: 0.4224
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 430s 1s/step - accuracy: 0.4102 - loss: 1.7036 - val_accuracy: 0.4191 - val_loss: 1.6850 - learning_rate: 1.0000e-04
# Epoch 7/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 718ms/step - accuracy: 0.4383 - loss: 1.6429
# Epoch 7:
# Train Metrics -> Loss: 1.6322, Accuracy: 0.4427, Precision: 0.4557, Recall: 0.4338
# Validation Metrics -> Loss: 1.7212, Accuracy: 0.4064, Precision: 0.4191, Recall: 0.4087
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 432s 1s/step - accuracy: 0.4383 - loss: 1.6428 - val_accuracy: 0.4064 - val_loss: 1.7212 - learning_rate: 1.0000e-04
# Epoch 8/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.4395 - loss: 1.5980
# Epoch 8:
# Train Metrics -> Loss: 1.6105, Accuracy: 0.4478, Precision: 0.4908, Recall: 0.4621
# Validation Metrics -> Loss: 1.6453, Accuracy: 0.4308, Precision: 0.4534, Recall: 0.4332
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 431s 1s/step - accuracy: 0.4395 - loss: 1.5980 - val_accuracy: 0.4308 - val_loss: 1.6453 - learning_rate: 1.0000e-04
# Epoch 9/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.4530 - loss: 1.6114
# Epoch 9:
# Train Metrics -> Loss: 1.6298, Accuracy: 0.4463, Precision: 0.4977, Recall: 0.4993
# Validation Metrics -> Loss: 1.5748, Accuracy: 0.4701, Precision: 0.4693, Recall: 0.4714
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 433s 1s/step - accuracy: 0.4530 - loss: 1.6115 - val_accuracy: 0.4701 - val_loss: 1.5748 - learning_rate: 1.0000e-04
# Epoch 10/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.4831 - loss: 1.5521
# Epoch 10:
# Train Metrics -> Loss: 1.5533, Accuracy: 0.4768, Precision: 0.5294, Recall: 0.5168
# Validation Metrics -> Loss: 1.5544, Accuracy: 0.4767, Precision: 0.4883, Recall: 0.4794
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 434s 1s/step - accuracy: 0.4831 - loss: 1.5521 - val_accuracy: 0.4767 - val_loss: 1.5544 - learning_rate: 1.0000e-04
# Epoch 11/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 688ms/step - accuracy: 0.4770 - loss: 1.5351
# Epoch 11:
# Train Metrics -> Loss: 1.5107, Accuracy: 0.4863, Precision: 0.5403, Recall: 0.5304
# Validation Metrics -> Loss: 1.5169, Accuracy: 0.4897, Precision: 0.4990, Recall: 0.4929
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 429s 1s/step - accuracy: 0.4771 - loss: 1.5350 - val_accuracy: 0.4897 - val_loss: 1.5169 - learning_rate: 1.0000e-04
# Epoch 12/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 681ms/step - accuracy: 0.5161 - loss: 1.4441
# Epoch 12:
# Train Metrics -> Loss: 1.4545, Accuracy: 0.5136, Precision: 0.5627, Recall: 0.5371
# Validation Metrics -> Loss: 1.5228, Accuracy: 0.4930, Precision: 0.5165, Recall: 0.4944
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 432s 1s/step - accuracy: 0.5161 - loss: 1.4441 - val_accuracy: 0.4930 - val_loss: 1.5228 - learning_rate: 1.0000e-04
# Epoch 13/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 686ms/step - accuracy: 0.5300 - loss: 1.4070
# Epoch 13:
# Train Metrics -> Loss: 1.3975, Accuracy: 0.5306, Precision: 0.5799, Recall: 0.5622
# Validation Metrics -> Loss: 1.4591, Accuracy: 0.5131, Precision: 0.5255, Recall: 0.5144
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - accuracy: 0.5300 - loss: 1.4069 - val_accuracy: 0.5131 - val_loss: 1.4591 - learning_rate: 1.0000e-04
# Epoch 14/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 694ms/step - accuracy: 0.5591 - loss: 1.3331
# Epoch 14:
# Train Metrics -> Loss: 1.3632, Accuracy: 0.5457, Precision: 0.5912, Recall: 0.5675
# Validation Metrics -> Loss: 1.4542, Accuracy: 0.5164, Precision: 0.5401, Recall: 0.5195
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 436s 1s/step - accuracy: 0.5591 - loss: 1.3333 - val_accuracy: 0.5164 - val_loss: 1.4542 - learning_rate: 1.0000e-04
# Epoch 15/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.5639 - loss: 1.3238
# Epoch 15:
# Train Metrics -> Loss: 1.3266, Accuracy: 0.5586, Precision: 0.5838, Recall: 0.5848
# Validation Metrics -> Loss: 1.4076, Accuracy: 0.5307, Precision: 0.5260, Recall: 0.5320
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 432s 1s/step - accuracy: 0.5639 - loss: 1.3238 - val_accuracy: 0.5307 - val_loss: 1.4076 - learning_rate: 1.0000e-04
# Epoch 16/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 694ms/step - accuracy: 0.5659 - loss: 1.3007
# Epoch 16:
# Train Metrics -> Loss: 1.3135, Accuracy: 0.5609, Precision: 0.6067, Recall: 0.5650
# Validation Metrics -> Loss: 1.4815, Accuracy: 0.5065, Precision: 0.5446, Recall: 0.5083
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 432s 1s/step - accuracy: 0.5659 - loss: 1.3007 - val_accuracy: 0.5065 - val_loss: 1.4815 - learning_rate: 1.0000e-04
# Epoch 17/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.5631 - loss: 1.2863
# Epoch 17:
# Train Metrics -> Loss: 1.2740, Accuracy: 0.5744, Precision: 0.6178, Recall: 0.6156
# Validation Metrics -> Loss: 1.3647, Accuracy: 0.5585, Precision: 0.5588, Recall: 0.5603
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 435s 1s/step - accuracy: 0.5631 - loss: 1.2862 - val_accuracy: 0.5585 - val_loss: 1.3647 - learning_rate: 1.0000e-04
# Epoch 18/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.5810 - loss: 1.2425
# Epoch 18:
# Train Metrics -> Loss: 1.2462, Accuracy: 0.5848, Precision: 0.6323, Recall: 0.6210
# Validation Metrics -> Loss: 1.3490, Accuracy: 0.5531, Precision: 0.5623, Recall: 0.5539
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 435s 1s/step - accuracy: 0.5810 - loss: 1.2425 - val_accuracy: 0.5531 - val_loss: 1.3490 - learning_rate: 1.0000e-04
# Epoch 19/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.5927 - loss: 1.2113
# Epoch 19:
# Train Metrics -> Loss: 1.2105, Accuracy: 0.5921, Precision: 0.6292, Recall: 0.6130
# Validation Metrics -> Loss: 1.3904, Accuracy: 0.5353, Precision: 0.5463, Recall: 0.5374
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 421s 1s/step - accuracy: 0.5927 - loss: 1.2113 - val_accuracy: 0.5353 - val_loss: 1.3904 - learning_rate: 1.0000e-04
# Epoch 20/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.6006 - loss: 1.2053
# Epoch 20:
# Train Metrics -> Loss: 1.2126, Accuracy: 0.5976, Precision: 0.6530, Recall: 0.6456
# Validation Metrics -> Loss: 1.3349, Accuracy: 0.5603, Precision: 0.5678, Recall: 0.5620
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 420s 1s/step - accuracy: 0.6006 - loss: 1.2053 - val_accuracy: 0.5603 - val_loss: 1.3349 - learning_rate: 1.0000e-04
# Epoch 21/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 721ms/step - accuracy: 0.6040 - loss: 1.1804
# Epoch 21:
# Train Metrics -> Loss: 1.1878, Accuracy: 0.6056, Precision: 0.6493, Recall: 0.6287
# Validation Metrics -> Loss: 1.3753, Accuracy: 0.5434, Precision: 0.5678, Recall: 0.5464
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 434s 1s/step - accuracy: 0.6040 - loss: 1.1804 - val_accuracy: 0.5434 - val_loss: 1.3753 - learning_rate: 1.0000e-04
# Epoch 22/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 720ms/step - accuracy: 0.6233 - loss: 1.1313
# Epoch 22:
# Train Metrics -> Loss: 1.1432, Accuracy: 0.6164, Precision: 0.6636, Recall: 0.6590
# Validation Metrics -> Loss: 1.3128, Accuracy: 0.5682, Precision: 0.5711, Recall: 0.5689
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 429s 1s/step - accuracy: 0.6232 - loss: 1.1314 - val_accuracy: 0.5682 - val_loss: 1.3128 - learning_rate: 1.0000e-04
# Epoch 23/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 716ms/step - accuracy: 0.6301 - loss: 1.1040
# Epoch 23:
# Train Metrics -> Loss: 1.1214, Accuracy: 0.6226, Precision: 0.6643, Recall: 0.6588
# Validation Metrics -> Loss: 1.3185, Accuracy: 0.5610, Precision: 0.5650, Recall: 0.5642
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 427s 1s/step - accuracy: 0.6301 - loss: 1.1041 - val_accuracy: 0.5610 - val_loss: 1.3185 - learning_rate: 1.0000e-04
# Epoch 24/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 710ms/step - accuracy: 0.6318 - loss: 1.0973
# Epoch 24:
# Train Metrics -> Loss: 1.1100, Accuracy: 0.6248, Precision: 0.6317, Recall: 0.6333
# Validation Metrics -> Loss: 1.3561, Accuracy: 0.5544, Precision: 0.5492, Recall: 0.5568
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - accuracy: 0.6317 - loss: 1.0973 - val_accuracy: 0.5544 - val_loss: 1.3561 - learning_rate: 1.0000e-04
# Epoch 25/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 664ms/step - accuracy: 0.6142 - loss: 1.1619
# Epoch 25:
# Train Metrics -> Loss: 1.2017, Accuracy: 0.5991, Precision: 0.6377, Recall: 0.5978
# Validation Metrics -> Loss: 1.4404, Accuracy: 0.5256, Precision: 0.5654, Recall: 0.5285
# ----------
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 415s 1s/step - accuracy: 0.6141 - loss: 1.1620 - val_accuracy: 0.5256 - val_loss: 1.4404 - learning_rate: 1.0000e-04
# Epoch 26/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.6347 - loss: 1.0883
# Epoch 26:
# Train Metrics -> Loss: 1.0845, Accuracy: 0.6372, Precision: 0.6295, Recall: 0.6270
# Validation Metrics -> Loss: 1.3776, Accuracy: 0.5498, Precision: 0.5519, Recall: 0.5511
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 433s 1s/step - accuracy: 0.6347 - loss: 1.0882 - val_accuracy: 0.5498 - val_loss: 1.3776 - learning_rate: 5.0000e-05
# Epoch 27/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 629ms/step - accuracy: 0.6152 - loss: 1.1411
# Epoch 27:
# Train Metrics -> Loss: 1.1002, Accuracy: 0.6288, Precision: 0.6733, Recall: 0.6746
# Validation Metrics -> Loss: 1.2899, Accuracy: 0.5817, Precision: 0.5799, Recall: 0.5827
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 425s 1s/step - accuracy: 0.6152 - loss: 1.1410 - val_accuracy: 0.5817 - val_loss: 1.2899 - learning_rate: 5.0000e-05
# Epoch 28/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.6514 - loss: 1.0439
# Epoch 28:
# Train Metrics -> Loss: 1.0449, Accuracy: 0.6506, Precision: 0.6933, Recall: 0.6893
# Validation Metrics -> Loss: 1.2706, Accuracy: 0.5865, Precision: 0.5888, Recall: 0.5884
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 433s 1s/step - accuracy: 0.6514 - loss: 1.0439 - val_accuracy: 0.5865 - val_loss: 1.2706 - learning_rate: 5.0000e-05
# Epoch 29/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 684ms/step - accuracy: 0.6736 - loss: 0.9951
# Epoch 29:
# Train Metrics -> Loss: 1.0098, Accuracy: 0.6665, Precision: 0.7011, Recall: 0.6955
# Validation Metrics -> Loss: 1.2767, Accuracy: 0.5778, Precision: 0.5816, Recall: 0.5800
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 435s 1s/step - accuracy: 0.6736 - loss: 0.9951 - val_accuracy: 0.5778 - val_loss: 1.2767 - learning_rate: 5.0000e-05
# Epoch 30/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 687ms/step - accuracy: 0.6785 - loss: 0.9604
# Epoch 30:
# Train Metrics -> Loss: 0.9872, Accuracy: 0.6704, Precision: 0.7024, Recall: 0.6975
# Validation Metrics -> Loss: 1.2748, Accuracy: 0.5837, Precision: 0.5862, Recall: 0.5849
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - accuracy: 0.6785 - loss: 0.9605 - val_accuracy: 0.5837 - val_loss: 1.2748 - learning_rate: 5.0000e-05
# Epoch 31/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 687ms/step - accuracy: 0.6697 - loss: 0.9669
# Epoch 31:
# Train Metrics -> Loss: 0.9620, Accuracy: 0.6732, Precision: 0.7050, Recall: 0.7020
# Validation Metrics -> Loss: 1.2769, Accuracy: 0.5878, Precision: 0.5867, Recall: 0.5895
# ----------
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 431s 1s/step - accuracy: 0.6697 - loss: 0.9669 - val_accuracy: 0.5878 - val_loss: 1.2769 - learning_rate: 5.0000e-05
# Epoch 32/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - accuracy: 0.6915 - loss: 0.9258
# Epoch 32:
# Train Metrics -> Loss: 0.9246, Accuracy: 0.6905, Precision: 0.7299, Recall: 0.7296
# Validation Metrics -> Loss: 1.2521, Accuracy: 0.5941, Precision: 0.5952, Recall: 0.5955
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 437s 1s/step - accuracy: 0.6915 - loss: 0.9258 - val_accuracy: 0.5941 - val_loss: 1.2521 - learning_rate: 2.5000e-05
# Epoch 33/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.7051 - loss: 0.8899
# Epoch 33:
# Train Metrics -> Loss: 0.8993, Accuracy: 0.7010, Precision: 0.7373, Recall: 0.7351
# Validation Metrics -> Loss: 1.2477, Accuracy: 0.5954, Precision: 0.5973, Recall: 0.5970
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 440s 1s/step - accuracy: 0.7051 - loss: 0.8899 - val_accuracy: 0.5954 - val_loss: 1.2477 - learning_rate: 2.5000e-05
# Epoch 34/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 689ms/step - accuracy: 0.7089 - loss: 0.8681
# Epoch 34:
# Train Metrics -> Loss: 0.8843, Accuracy: 0.7065, Precision: 0.7445, Recall: 0.7385
# Validation Metrics -> Loss: 1.2496, Accuracy: 0.5985, Precision: 0.6016, Recall: 0.5997
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 430s 1s/step - accuracy: 0.7089 - loss: 0.8682 - val_accuracy: 0.5985 - val_loss: 1.2496 - learning_rate: 2.5000e-05
# Epoch 35/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - accuracy: 0.7104 - loss: 0.8763
# Epoch 35:
# Train Metrics -> Loss: 0.8751, Accuracy: 0.7097, Precision: 0.7451, Recall: 0.7452
# Validation Metrics -> Loss: 1.2474, Accuracy: 0.6038, Precision: 0.6031, Recall: 0.6051
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 441s 1s/step - accuracy: 0.7104 - loss: 0.8763 - val_accuracy: 0.6038 - val_loss: 1.2474 - learning_rate: 2.5000e-05
# Epoch 36/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.7157 - loss: 0.8454
# Epoch 36:
# Train Metrics -> Loss: 0.8510, Accuracy: 0.7146, Precision: 0.7485, Recall: 0.7441
# Validation Metrics -> Loss: 1.2588, Accuracy: 0.5975, Precision: 0.6019, Recall: 0.5991
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - accuracy: 0.7157 - loss: 0.8454 - val_accuracy: 0.5975 - val_loss: 1.2588 - learning_rate: 2.5000e-05
# Epoch 37/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.7233 - loss: 0.8417
# Epoch 37:
# Train Metrics -> Loss: 0.8452, Accuracy: 0.7192, Precision: 0.7557, Recall: 0.7558
# Validation Metrics -> Loss: 1.2519, Accuracy: 0.5977, Precision: 0.5959, Recall: 0.5989
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - accuracy: 0.7233 - loss: 0.8417 - val_accuracy: 0.5977 - val_loss: 1.2519 - learning_rate: 2.5000e-05
# Epoch 38/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - accuracy: 0.7272 - loss: 0.8185
# Epoch 38:
# Train Metrics -> Loss: 0.8269, Accuracy: 0.7263, Precision: 0.7624, Recall: 0.7599
# Validation Metrics -> Loss: 1.2537, Accuracy: 0.6036, Precision: 0.6024, Recall: 0.6053
# ----------
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 425s 1s/step - accuracy: 0.7272 - loss: 0.8185 - val_accuracy: 0.6036 - val_loss: 1.2537 - learning_rate: 2.5000e-05
# Epoch 39/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.7309 - loss: 0.8018
# Epoch 39:
# Train Metrics -> Loss: 0.7959, Accuracy: 0.7369, Precision: 0.7653, Recall: 0.7656
# Validation Metrics -> Loss: 1.2445, Accuracy: 0.6018, Precision: 0.6022, Recall: 0.6027
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - accuracy: 0.7309 - loss: 0.8018 - val_accuracy: 0.6018 - val_loss: 1.2445 - learning_rate: 1.2500e-05
# Epoch 40/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 681ms/step - accuracy: 0.7382 - loss: 0.7919
# Epoch 40:
# Train Metrics -> Loss: 0.7891, Accuracy: 0.7369, Precision: 0.7680, Recall: 0.7677
# Validation Metrics -> Loss: 1.2495, Accuracy: 0.6036, Precision: 0.6013, Recall: 0.6047
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - accuracy: 0.7382 - loss: 0.7919 - val_accuracy: 0.6036 - val_loss: 1.2495 - learning_rate: 1.2500e-05
# Epoch 41/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.7418 - loss: 0.7842
# Epoch 41:
# Train Metrics -> Loss: 0.7924, Accuracy: 0.7370, Precision: 0.7682, Recall: 0.7665
# Validation Metrics -> Loss: 1.2521, Accuracy: 0.6051, Precision: 0.6054, Recall: 0.6066
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 433s 1s/step - accuracy: 0.7418 - loss: 0.7842 - val_accuracy: 0.6051 - val_loss: 1.2521 - learning_rate: 1.2500e-05
# Epoch 42/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 679ms/step - accuracy: 0.7392 - loss: 0.7823
# Epoch 42:
# Train Metrics -> Loss: 0.7906, Accuracy: 0.7376, Precision: 0.7700, Recall: 0.7679
# Validation Metrics -> Loss: 1.2483, Accuracy: 0.6054, Precision: 0.6049, Recall: 0.6059
# ----------
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 431s 1s/step - accuracy: 0.7392 - loss: 0.7823 - val_accuracy: 0.6054 - val_loss: 1.2483 - learning_rate: 1.2500e-05
# Epoch 43/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.7429 - loss: 0.8013
# Epoch 43:
# Train Metrics -> Loss: 0.7897, Accuracy: 0.7427, Precision: 0.7718, Recall: 0.7693
# Validation Metrics -> Loss: 1.2505, Accuracy: 0.6018, Precision: 0.6025, Recall: 0.6029
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 438s 1s/step - accuracy: 0.7429 - loss: 0.8013 - val_accuracy: 0.6018 - val_loss: 1.2505 - learning_rate: 6.2500e-06
# Epoch 44/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.7447 - loss: 0.7665
# Epoch 44:
# Train Metrics -> Loss: 0.7747, Accuracy: 0.7445, Precision: 0.7742, Recall: 0.7740
# Validation Metrics -> Loss: 1.2518, Accuracy: 0.6023, Precision: 0.6005, Recall: 0.6034
# ----------
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 406s 1s/step - accuracy: 0.7447 - loss: 0.7665 - val_accuracy: 0.6023 - val_loss: 1.2518 - learning_rate: 6.2500e-06
#
# Training Complete. Best Epoch: 42
# Training Metrics -> Loss: 0.7906, Accuracy: 0.7376, Precision: 0.7700, Recall: 0.7679
# Validation Metrics -> Loss: 1.2483, Accuracy: 0.6054, Precision: 0.6049, Recall: 0.6059
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 34s 276ms/step - accuracy: 0.6178 - loss: 1.2000
#
# Test Metrics -> Loss: 1.2445, Accuracy: 0.6018, Precision: 0.6022, Recall: 0.6027
