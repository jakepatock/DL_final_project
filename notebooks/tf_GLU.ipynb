# %%
import tensorflow as tf
from tensorflow.keras.utils import get_file
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data preparation
def preprocess_image(image, label, image_size=(224, 224)):
    image = tf.image.resize(image, image_size)
    image = tf.image.convert_image_dtype(image, tf.float32)
    return image, label

def prepare_dataset(batch_size=32, image_size=(224, 224), test_split=0.2):
    # Download the Imagenette dataset
    dataset_url = "https://s3.amazonaws.com/fast-ai-imageclas/imagenette2.tgz"
    dataset_path = get_file("imagenette2", dataset_url, untar=True)

    # Load the full training dataset
    full_train_ds = tf.keras.utils.image_dataset_from_directory(
        dataset_path + "/train",
        image_size=image_size,
        batch_size=batch_size
    )

    # Split into training and test datasets
    dataset_size = len(full_train_ds)
    test_size = int(dataset_size * test_split)
    train_size = dataset_size - test_size

    train_ds = full_train_ds.take(train_size)
    test_ds = full_train_ds.skip(train_size)

    # Load validation dataset
    val_ds = tf.keras.utils.image_dataset_from_directory(
        dataset_path + "/val",
        image_size=image_size,
        batch_size=batch_size
    )

    # Apply preprocessing, caching, and prefetching
    train_ds = train_ds.map(lambda x, y: preprocess_image(x, y, image_size)).cache().shuffle(1000).prefetch(tf.data.AUTOTUNE)
    test_ds = test_ds.map(lambda x, y: preprocess_image(x, y, image_size)).cache().prefetch(tf.data.AUTOTUNE)
    val_ds = val_ds.map(lambda x, y: preprocess_image(x, y, image_size)).cache().prefetch(tf.data.AUTOTUNE)

    return train_ds, val_ds, test_ds

batch_size = 32
image_size = (224, 224)
train_ds, val_ds, test_ds = prepare_dataset(batch_size=batch_size, image_size=image_size, test_split=0.2)
# Out:
# Found 9469 files belonging to 10 classes.
# Found 3925 files belonging to 10 classes.

# %%
# Gated Linear Unit (GLU)
class GatedLinearUnit(tf.keras.layers.Layer):
    def __init__(self, hidden_dim):
        super(GatedLinearUnit, self).__init__()
        self.hidden_dim = hidden_dim
        self.linear = tf.keras.layers.Dense(hidden_dim)
        self.gate = tf.keras.layers.Dense(hidden_dim)

    def call(self, inputs):
        # Apply GLU: sigmoid(gate) * relu(linear)
        gate = tf.sigmoid(self.gate(inputs))
        linear = tf.nn.relu(self.linear(inputs))
        return gate * linear

# %%
# Transformer Encoder with GLU
class TransformerEncoderLayer(tf.keras.layers.Layer):
    def __init__(self, embedding_dim, num_heads, ff_hidden_dim, dropout_rate):
        super(TransformerEncoderLayer, self).__init__()
        self.mha = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=embedding_dim)
        self.ffn = tf.keras.Sequential([
            GatedLinearUnit(ff_hidden_dim),  # Using GLU here
            tf.keras.layers.Dense(embedding_dim),
        ])
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = tf.keras.layers.Dropout(dropout_rate)
        self.dropout2 = tf.keras.layers.Dropout(dropout_rate)

    def call(self, inputs, training):
        # Multi-head self-attention
        attn_output = self.mha(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)

        # Feed-forward network with GLU
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# %%
# Vision Transformer
class VisionTransformer(tf.keras.Model):
    def __init__(self, image_size, patch_size, num_classes, embedding_dim, num_heads, num_layers, ff_hidden_dim, dropout_rate):
        super(VisionTransformer, self).__init__()
        self.patch_size = patch_size
        self.num_patches = (image_size // patch_size) ** 2
        self.embedding_dim = embedding_dim

        # Patch embedding layer
        self.patch_embedding = tf.keras.layers.Conv2D(embedding_dim, patch_size, strides=patch_size, padding='valid')

        # Positional embeddings using sine and cosine
        self.pos_embedding = self.create_sin_cos_positional_embeddings(self.num_patches, embedding_dim)

        # Prepend CLS token
        self.cls_token = tf.Variable(tf.zeros([1, 1, embedding_dim]), trainable=True)

        # Transformer encoder layers with GLU
        self.transformer_layers = [
            TransformerEncoderLayer(embedding_dim, num_heads, ff_hidden_dim, dropout_rate)
            for _ in range(num_layers)
        ]

        # Classification head
        self.cls_head = tf.keras.Sequential([
            tf.keras.layers.Dense(num_classes, activation='softmax')
        ])

    def create_sin_cos_positional_embeddings(self, num_patches, embedding_dim):
        position = np.arange(num_patches)[:, np.newaxis]
        div_term = np.exp(np.arange(0, embedding_dim, 2) * -(np.log(10000.0) / embedding_dim))

        pos_encoding = np.zeros((num_patches, embedding_dim))
        pos_encoding[:, 0::2] = np.sin(position * div_term)
        pos_encoding[:, 1::2] = np.cos(position * div_term)

        return tf.constant(pos_encoding[np.newaxis, :, :], dtype=tf.float32)

    def call(self, inputs, training=False):
        # Extract patches and embed
        patches = self.patch_embedding(inputs)
        patches = tf.reshape(patches, [-1, self.num_patches, self.embedding_dim])

        # Add positional embeddings
        patches += self.pos_embedding

        # Prepend the CLS token
        batch_size = tf.shape(patches)[0]
        cls_tokens = tf.tile(self.cls_token, [batch_size, 1, 1])
        x = tf.concat([cls_tokens, patches], axis=1)

        # Apply transformer encoder layers
        for layer in self.transformer_layers:
            x = layer(x, training=training)

        # Extract CLS token and apply classification head
        cls_token = x[:, 0]  # CLS token
        return self.cls_head(cls_token)

# %%
class PrintMetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self):
        super(PrintMetricsCallback, self).__init__()
        self.best_epoch = 0
        self.best_val_loss = float('inf')
        self.best_metrics = {}

    def on_epoch_end(self, epoch, logs=None):
        # Print the metrics after each epoch
        print(f"\nEpoch {epoch + 1}:")
        print(f"  Training Loss: {logs['loss']:.4f}")
        print(f"  Training Accuracy: {logs['accuracy']:.4f}")
        print(f"  Validation Loss: {logs['val_loss']:.4f}")
        print(f"  Validation Accuracy: {logs['val_accuracy']:.4f}")
        print('-' * 10)

        # Track the best epoch based on validation loss
        val_loss = logs.get('val_loss')
        if val_loss < self.best_val_loss:
            self.best_val_loss = val_loss
            self.best_epoch = epoch
            self.best_metrics = logs

# %%
# Initialize and compile the model
model = VisionTransformer(
    image_size=224,
    patch_size=16,
    num_classes=10,
    embedding_dim=48,
    num_heads=12,
    num_layers=12,
    ff_hidden_dim=3072,
    dropout_rate=0.1
)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# Early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# ReduceLROnPlateau
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6
)

# Create an instance of the PrintMetricsCallback
print_metrics_callback = PrintMetricsCallback()

# Train the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=1000,
    callbacks=[early_stopping, reduce_lr_on_plateau, print_metrics_callback]
)
# After training, retrieve the best epoch metrics
best_epoch = print_metrics_callback.best_epoch
best_metrics = print_metrics_callback.best_metrics

# Evaluate the model on the test dataset at the best epoch
test_loss, test_accuracy = model.evaluate(test_ds)

# Print the best epoch along with the metrics
print(f"\nBest Epoch: {best_epoch + 1}")
print(f"  Training Loss: {best_metrics['loss']:.4f}")
print(f"  Training Accuracy: {best_metrics['accuracy']:.4f}")
print(f"  Validation Loss: {best_metrics['val_loss']:.4f}")
print(f"  Validation Accuracy: {best_metrics['val_accuracy']:.4f}")
print(f"  Test Loss: {test_loss:.4f}")
print(f"  Test Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch 1/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.1548 - loss: 2.3245
# Epoch 1:
#   Training Loss: 2.2006
#   Training Accuracy: 0.1937
#   Validation Loss: 2.0517
#   Validation Accuracy: 0.2517
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 851s 4s/step - accuracy: 0.1550 - loss: 2.3240 - val_accuracy: 0.2517 - val_loss: 2.0517 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2920 - loss: 1.9859
# Epoch 2:
#   Training Loss: 1.9363
#   Training Accuracy: 0.3141
#   Validation Loss: 1.8341
#   Validation Accuracy: 0.3689
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 877s 4s/step - accuracy: 0.2921 - loss: 1.9857 - val_accuracy: 0.3689 - val_loss: 1.8341 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3748 - loss: 1.8044
# Epoch 3:
#   Training Loss: 1.7870
#   Training Accuracy: 0.3813
#   Validation Loss: 1.7303
#   Validation Accuracy: 0.3987
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 871s 4s/step - accuracy: 0.3749 - loss: 1.8044 - val_accuracy: 0.3987 - val_loss: 1.7303 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4075 - loss: 1.7015
# Epoch 4:
#   Training Loss: 1.6843
#   Training Accuracy: 0.4159
#   Validation Loss: 1.6078
#   Validation Accuracy: 0.4550
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 871s 4s/step - accuracy: 0.4075 - loss: 1.7015 - val_accuracy: 0.4550 - val_loss: 1.6078 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4587 - loss: 1.5919
# Epoch 5:
#   Training Loss: 1.5915
#   Training Accuracy: 0.4511
#   Validation Loss: 1.6109
#   Validation Accuracy: 0.4464
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 871s 4s/step - accuracy: 0.4586 - loss: 1.5918 - val_accuracy: 0.4464 - val_loss: 1.6109 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4620 - loss: 1.5461
# Epoch 6:
#   Training Loss: 1.5218
#   Training Accuracy: 0.4706
#   Validation Loss: 1.7397
#   Validation Accuracy: 0.4110
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 878s 4s/step - accuracy: 0.4621 - loss: 1.5460 - val_accuracy: 0.4110 - val_loss: 1.7397 - learning_rate: 1.0000e-04
# Epoch 7/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4834 - loss: 1.4762
# Epoch 7:
#   Training Loss: 1.4646
#   Training Accuracy: 0.4925
#   Validation Loss: 1.4837
#   Validation Accuracy: 0.4996
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 876s 4s/step - accuracy: 0.4835 - loss: 1.4762 - val_accuracy: 0.4996 - val_loss: 1.4837 - learning_rate: 1.0000e-04
# Epoch 8/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5196 - loss: 1.3995
# Epoch 8:
#   Training Loss: 1.3978
#   Training Accuracy: 0.5236
#   Validation Loss: 1.4972
#   Validation Accuracy: 0.4986
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 872s 4s/step - accuracy: 0.5196 - loss: 1.3995 - val_accuracy: 0.4986 - val_loss: 1.4972 - learning_rate: 1.0000e-04
# Epoch 9/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5351 - loss: 1.3479
# Epoch 9:
#   Training Loss: 1.3553
#   Training Accuracy: 0.5369
#   Validation Loss: 1.4974
#   Validation Accuracy: 0.5014
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 879s 4s/step - accuracy: 0.5351 - loss: 1.3479 - val_accuracy: 0.5014 - val_loss: 1.4974 - learning_rate: 1.0000e-04
# Epoch 10/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5600 - loss: 1.2817
# Epoch 10:
#   Training Loss: 1.3069
#   Training Accuracy: 0.5516
#   Validation Loss: 1.4545
#   Validation Accuracy: 0.5197
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 881s 4s/step - accuracy: 0.5599 - loss: 1.2818 - val_accuracy: 0.5197 - val_loss: 1.4545 - learning_rate: 1.0000e-04
# Epoch 11/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5540 - loss: 1.3087
# Epoch 11:
#   Training Loss: 1.2876
#   Training Accuracy: 0.5629
#   Validation Loss: 1.3621
#   Validation Accuracy: 0.5501
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 877s 4s/step - accuracy: 0.5540 - loss: 1.3087 - val_accuracy: 0.5501 - val_loss: 1.3621 - learning_rate: 1.0000e-04
# Epoch 12/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5792 - loss: 1.2383
# Epoch 12:
#   Training Loss: 1.2332
#   Training Accuracy: 0.5783
#   Validation Loss: 1.3724
#   Validation Accuracy: 0.5427
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 877s 4s/step - accuracy: 0.5792 - loss: 1.2383 - val_accuracy: 0.5427 - val_loss: 1.3724 - learning_rate: 1.0000e-04
# Epoch 13/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5836 - loss: 1.2099
# Epoch 13:
#   Training Loss: 1.2130
#   Training Accuracy: 0.5835
#   Validation Loss: 1.3320
#   Validation Accuracy: 0.5572
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 876s 4s/step - accuracy: 0.5836 - loss: 1.2099 - val_accuracy: 0.5572 - val_loss: 1.3320 - learning_rate: 1.0000e-04
# Epoch 14/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6114 - loss: 1.1525
# Epoch 14:
#   Training Loss: 1.1659
#   Training Accuracy: 0.6068
#   Validation Loss: 1.3469
#   Validation Accuracy: 0.5455
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 871s 4s/step - accuracy: 0.6114 - loss: 1.1526 - val_accuracy: 0.5455 - val_loss: 1.3469 - learning_rate: 1.0000e-04
# Epoch 15/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6208 - loss: 1.1178
# Epoch 15:
#   Training Loss: 1.1409
#   Training Accuracy: 0.6096
#   Validation Loss: 1.3204
#   Validation Accuracy: 0.5633
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 871s 4s/step - accuracy: 0.6207 - loss: 1.1179 - val_accuracy: 0.5633 - val_loss: 1.3204 - learning_rate: 1.0000e-04
# Epoch 16/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6216 - loss: 1.1097
# Epoch 16:
#   Training Loss: 1.1017
#   Training Accuracy: 0.6267
#   Validation Loss: 1.2864
#   Validation Accuracy: 0.5702
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 868s 4s/step - accuracy: 0.6217 - loss: 1.1097 - val_accuracy: 0.5702 - val_loss: 1.2864 - learning_rate: 1.0000e-04
# Epoch 17/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6482 - loss: 1.0376
# Epoch 17:
#   Training Loss: 1.0686
#   Training Accuracy: 0.6390
#   Validation Loss: 1.2751
#   Validation Accuracy: 0.5827
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 865s 4s/step - accuracy: 0.6482 - loss: 1.0377 - val_accuracy: 0.5827 - val_loss: 1.2751 - learning_rate: 1.0000e-04
# Epoch 18/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6567 - loss: 1.0144
# Epoch 18:
#   Training Loss: 1.0393
#   Training Accuracy: 0.6478
#   Validation Loss: 1.2636
#   Validation Accuracy: 0.5918
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 871s 4s/step - accuracy: 0.6567 - loss: 1.0145 - val_accuracy: 0.5918 - val_loss: 1.2636 - learning_rate: 1.0000e-04
# Epoch 19/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6522 - loss: 1.0137
# Epoch 19:
#   Training Loss: 1.0136
#   Training Accuracy: 0.6556
#   Validation Loss: 1.2722
#   Validation Accuracy: 0.5824
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 879s 4s/step - accuracy: 0.6522 - loss: 1.0137 - val_accuracy: 0.5824 - val_loss: 1.2722 - learning_rate: 1.0000e-04
# Epoch 20/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6558 - loss: 1.0060
# Epoch 20:
#   Training Loss: 0.9884
#   Training Accuracy: 0.6634
#   Validation Loss: 1.2331
#   Validation Accuracy: 0.6056
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 873s 4s/step - accuracy: 0.6559 - loss: 1.0060 - val_accuracy: 0.6056 - val_loss: 1.2331 - learning_rate: 1.0000e-04
# Epoch 21/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6768 - loss: 0.9702
# Epoch 21:
#   Training Loss: 0.9679
#   Training Accuracy: 0.6734
#   Validation Loss: 1.2517
#   Validation Accuracy: 0.6054
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 877s 4s/step - accuracy: 0.6768 - loss: 0.9702 - val_accuracy: 0.6054 - val_loss: 1.2517 - learning_rate: 1.0000e-04
# Epoch 22/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6722 - loss: 0.9496
# Epoch 22:
#   Training Loss: 0.9420
#   Training Accuracy: 0.6759
#   Validation Loss: 1.2252
#   Validation Accuracy: 0.5975
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 875s 4s/step - accuracy: 0.6722 - loss: 0.9496 - val_accuracy: 0.5975 - val_loss: 1.2252 - learning_rate: 1.0000e-04
# Epoch 23/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7011 - loss: 0.8916
# Epoch 23:
#   Training Loss: 0.9204
#   Training Accuracy: 0.6892
#   Validation Loss: 1.2518
#   Validation Accuracy: 0.6003
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 900s 4s/step - accuracy: 0.7011 - loss: 0.8917 - val_accuracy: 0.6003 - val_loss: 1.2518 - learning_rate: 1.0000e-04
# Epoch 24/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7038 - loss: 0.8841
# Epoch 24:
#   Training Loss: 0.8811
#   Training Accuracy: 0.7028
#   Validation Loss: 1.2349
#   Validation Accuracy: 0.6046
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 889s 4s/step - accuracy: 0.7038 - loss: 0.8840 - val_accuracy: 0.6046 - val_loss: 1.2349 - learning_rate: 1.0000e-04
# Epoch 25/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7156 - loss: 0.8382
# Epoch 25:
#   Training Loss: 0.8605
#   Training Accuracy: 0.7106
#   Validation Loss: 1.2920
#   Validation Accuracy: 0.5880
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 844s 4s/step - accuracy: 0.7156 - loss: 0.8383 - val_accuracy: 0.5880 - val_loss: 1.2920 - learning_rate: 1.0000e-04
# Epoch 26/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7376 - loss: 0.7909
# Epoch 26:
#   Training Loss: 0.7553
#   Training Accuracy: 0.7504
#   Validation Loss: 1.2124
#   Validation Accuracy: 0.6217
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 590s 2s/step - accuracy: 0.7376 - loss: 0.7907 - val_accuracy: 0.6217 - val_loss: 1.2124 - learning_rate: 5.0000e-05
# Epoch 27/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7741 - loss: 0.6893
# Epoch 27:
#   Training Loss: 0.7051
#   Training Accuracy: 0.7632
#   Validation Loss: 1.1841
#   Validation Accuracy: 0.6288
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 589s 2s/step - accuracy: 0.7741 - loss: 0.6894 - val_accuracy: 0.6288 - val_loss: 1.1841 - learning_rate: 5.0000e-05
# Epoch 28/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7841 - loss: 0.6570
# Epoch 28:
#   Training Loss: 0.6718
#   Training Accuracy: 0.7798
#   Validation Loss: 1.2200
#   Validation Accuracy: 0.6247
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 592s 3s/step - accuracy: 0.7841 - loss: 0.6571 - val_accuracy: 0.6247 - val_loss: 1.2200 - learning_rate: 5.0000e-05
# Epoch 29/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7876 - loss: 0.6398
# Epoch 29:
#   Training Loss: 0.6551
#   Training Accuracy: 0.7818
#   Validation Loss: 1.2038
#   Validation Accuracy: 0.6298
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 592s 3s/step - accuracy: 0.7876 - loss: 0.6399 - val_accuracy: 0.6298 - val_loss: 1.2038 - learning_rate: 5.0000e-05
# Epoch 30/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7864 - loss: 0.6247
# Epoch 30:
#   Training Loss: 0.6191
#   Training Accuracy: 0.7896
#   Validation Loss: 1.2110
#   Validation Accuracy: 0.6324
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 593s 3s/step - accuracy: 0.7864 - loss: 0.6247 - val_accuracy: 0.6324 - val_loss: 1.2110 - learning_rate: 5.0000e-05
# Epoch 31/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8270 - loss: 0.5358
# Epoch 31:
#   Training Loss: 0.5467
#   Training Accuracy: 0.8221
#   Validation Loss: 1.2041
#   Validation Accuracy: 0.6354
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 795s 3s/step - accuracy: 0.8270 - loss: 0.5358 - val_accuracy: 0.6354 - val_loss: 1.2041 - learning_rate: 2.5000e-05
# Epoch 32/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8414 - loss: 0.5045
# Epoch 32:
#   Training Loss: 0.5225
#   Training Accuracy: 0.8307
#   Validation Loss: 1.2167
#   Validation Accuracy: 0.6336
# ----------
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 957s 4s/step - accuracy: 0.8414 - loss: 0.5045 - val_accuracy: 0.6336 - val_loss: 1.2167 - learning_rate: 2.5000e-05
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.6679 - loss: 1.0330
#
# Best Epoch: 27
#   Training Loss: 0.7051
#   Training Accuracy: 0.7632
#   Validation Loss: 1.1841
#   Validation Accuracy: 0.6288
#   Test Loss: 1.0987
#   Test Accuracy: 0.6462

# %%
# Extract metrics from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Get the best epoch and metrics from the callback
best_epoch = print_metrics_callback.best_epoch
best_train_loss = print_metrics_callback.best_metrics['loss']
best_train_accuracy = print_metrics_callback.best_metrics['accuracy']
best_val_loss = print_metrics_callback.best_metrics['val_loss']
best_val_accuracy = print_metrics_callback.best_metrics['val_accuracy']

# Plot Training and Validation Loss
plt.figure(figsize=(12, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss')
plt.axvline(x=best_epoch + 1, color='r', linestyle='--', label=f'Best Epoch')
plt.axhline(y=best_val_loss, color='g', linestyle='--', label=f'Best Loss')
plt.title('Loss Across Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_accuracy) + 1), train_accuracy, label='Training Accuracy')
plt.plot(range(1, len(val_accuracy) + 1), val_accuracy, label='Validation Accuracy')
plt.axvline(x=best_epoch + 1, color='r', linestyle='--', label=f'Best Epoch')
plt.axhline(y=best_val_accuracy, color='b', linestyle='--', label=f'Best Accuracy')
plt.title('Accuracy Across Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
